# %%
dbutils.notebook.run(path= "./Child Notebook", timeout_seconds=160)

# %%
rtv = dbutils.notebook.run(path= "./Child Notebook", timeout_seconds=160,arguments={"technology":"2g","Customer_name":"Rahul"}
)
