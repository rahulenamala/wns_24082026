# %%
print("Invoked child notebook")

# %%
print("Invoked child notebook - 2")
dbutils.notebook.exit("Success")

# %%
print("Invoked child notebook - 3")

# %%
dbutils.widgets.dropdown(
    name="technology",
    defaultValue="2g",
    choices=["2g", "3g","4g", "5g"],
    label="Technology",
)

# %%
dbutils.widgets.text(
    name="customer_name",
    defaultValue="Rahul",
    label="Name"
)

# %%
print(dbutils.widgets.get("technology"))
print(dbutils.widgets.get("customer_name"))
